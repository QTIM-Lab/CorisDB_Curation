# %%
print('hi')
# Out:
# hi

# %%
import pandas as pd

# %%
# Read the two CSV files into Pandas DataFrames
df1 = pd.read_csv('/projects/CorisDB_Curation/postgres/queries_and_stats/queries/Glaucoma/OCT_CDR_CFP_Merge/recent_OCT_CFP_CDRs_interpolated.csv')
# df2 = pd.read_csv('/projects/coris_db/postgres/queries_and_stats/queries/Glaucoma/OCT_CDR_CFP_Merge/results_final.csv')
df2 = pd.read_csv('/projects/CorisDB_Curation/postgres/queries_and_stats/queries/Glaucoma/OCT_CDR_CFP_Merge/pred_and_gt_with_avg_all.csv')
# Drop duplicates from df2 based on the filename column
# df2 = df2.drop_duplicates(subset=['filename'])

# %%
df1
# Out:
#                                                filename cfp_datetime  \
# 0     AxisUCH01_10034_77265_201502250751527525b51a9c...   2015-02-25
# 1     AxisUCH01_10034_77265_20150225075152924ecb69af...   2015-02-25
# 2     AxisUCH01_10062_120744_20160520133755017211352...   2016-05-20
# 3     AxisUCH01_10062_120744_201605201337551735a4625...   2016-05-20
# 4     AxisUCH01_10062_53888_20140507154810928573be24...   2014-05-07
# ...                                                 ...          ...
# 6617  axis01_9976_158094_20170323083817871a0b30d4f34...   2017-03-23
# 6618  axis01_9976_158094_20170323083817934d28ddfafcf...   2017-03-23
# 6619  axis01_9976_202616_201801221340470714cf539312f...   2018-01-22
# 6620  axis01_9976_202616_201801221340473211adc10aa99...   2018-01-22
# 6621  axis01_99_522768_20220610101336593255cf3dc700e...   2022-06-10
#
#      oct_datetime  verticalcd
# 0      2015-01-07    0.629630
# 1      2015-01-07    0.666667
# 2      2016-01-15    0.824561
# ...

# %%
df2
# Out:
#                                                 filename  pred_cdr devname  \
# 0      axis01_27169_289428_202102221220567096e1edc766...  0.519481   Nidek
# 1      axis01_32338_403609_20210208082844395e5d17251a...  0.842333   Nidek
# 2      axis01_34955_325605_201912230900137642331e57a9...  0.660173   Nidek
# 3      axis01_30687_329544_2020011510343392836de7f08a...  0.638528   Nidek
# 4      AxisUCH01_3369_9390_20121231120827201f4d42446f...  0.590022  NonMyd
# ...                                                  ...       ...     ...
# 22723  axis01_2783_360245_2020072115460092232f89c7318...  0.611714  NonMyd
# 22724  axis01_19641_220546_20180508170648435713d313cd...  0.659483  NonMyd
# 22725  axis01_12462_245395_20181002110141660aa4aae1e7...  0.504348  NonMyd
# 22726  axis01_5389_499072_2022032912533580245dea8a99c...  0.538126  NonMyd
# 22727  AxisUCH01_433_74630_20150126142338027eb7d8ddeb...  0.640693  NonMyd
#
#       fileeye  pat_mrn  cdr_value        date  pred_cdr_avg
# ...

# %%
# Specify the column on which you want to join
# Assuming 'common_column' is the column name common in both files
common_column = 'filename'

# Perform the join operation
# Assuming you want an inner join, change 'how' parameter accordingly for other types of joins
result = pd.merge(df1, df2, on=common_column, how='left')

# Print the result or do further operations with it
print(result)
# Out:
#                                                filename cfp_datetime  \
# 0     AxisUCH01_10034_77265_201502250751527525b51a9c...   2015-02-25
# 1     AxisUCH01_10034_77265_20150225075152924ecb69af...   2015-02-25
# 2     AxisUCH01_10062_120744_20160520133755017211352...   2016-05-20
# 3     AxisUCH01_10062_120744_201605201337551735a4625...   2016-05-20
# 4     AxisUCH01_10062_53888_20140507154810928573be24...   2014-05-07
# ...                                                 ...          ...
# 6617  axis01_9976_158094_20170323083817871a0b30d4f34...   2017-03-23
# 6618  axis01_9976_158094_20170323083817934d28ddfafcf...   2017-03-23
# 6619  axis01_9976_202616_201801221340470714cf539312f...   2018-01-22
# 6620  axis01_9976_202616_201801221340473211adc10aa99...   2018-01-22
# 6621  axis01_99_522768_20220610101336593255cf3dc700e...   2022-06-10
#
#      oct_datetime  verticalcd  pred_cdr devname fileeye  pat_mrn  cdr_value  \
# ...

# %%
result
# Out:
#                                                filename cfp_datetime  \
# 0     AxisUCH01_10034_77265_201502250751527525b51a9c...   2015-02-25
# 1     AxisUCH01_10034_77265_20150225075152924ecb69af...   2015-02-25
# 2     AxisUCH01_10062_120744_20160520133755017211352...   2016-05-20
# 3     AxisUCH01_10062_120744_201605201337551735a4625...   2016-05-20
# 4     AxisUCH01_10062_53888_20140507154810928573be24...   2014-05-07
# ...                                                 ...          ...
# 6617  axis01_9976_158094_20170323083817871a0b30d4f34...   2017-03-23
# 6618  axis01_9976_158094_20170323083817934d28ddfafcf...   2017-03-23
# 6619  axis01_9976_202616_201801221340470714cf539312f...   2018-01-22
# 6620  axis01_9976_202616_201801221340473211adc10aa99...   2018-01-22
# 6621  axis01_99_522768_20220610101336593255cf3dc700e...   2022-06-10
#
#      oct_datetime  verticalcd  pred_cdr devname fileeye  pat_mrn  cdr_value  \
# ...

# %%
result.to_csv('/projects/CorisDB_Curation/postgres/queries_and_stats/queries/Glaucoma/OCT_CDR_CFP_Merge/OCT_CFP_CDRs_preds_interpolated.csv', index=False)
