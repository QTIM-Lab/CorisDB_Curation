# %%
import pandas as pd

# %%
df_oct = pd.read_csv('OCT_CDRs.csv')
# df_cfp = pd.read_csv('all_raw.csv')
df_cfp = pd.read_csv('/projects/coris_db/postgres/queries_and_stats/queries/Glaucoma/OCT_CDR_CFP_Merge/results_final.csv')
# Out:
# /tmp/ipykernel_1934094/3982227864.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_oct = pd.read_csv('OCT_CDRs.csv')

# %%
# Filter rows where the value in the "value" column is less than 0.001
filtered_df = df_oct[df_oct['verticalcd'] < 0.03]

# %%
filtered_df
# Out:
#                                              filenamepath patientmrn  \
# 85164   /data/PACS/forum/2014/2/11/1.2.276.0.75.2.2.42...    2315722
# 98721   /data/PACS/forum/2015/8/17/1.2.276.0.75.2.2.42...    3923435
# 99109   /data/PACS/forum/2015/9/2/1.2.276.0.75.2.2.42....    5340750
# 104961  /data/PACS/forum/2016/5/13/1.2.276.0.75.2.2.42...    1287504
#
#         acquisitiondatetime                 sopclassuid modality laterality  \
# 85164          2.014021e+13  1.2.840.10008.5.1.4.1.1.66      OPT          R
# 98721          2.015082e+13  1.2.840.10008.5.1.4.1.1.66      OPT          L
# 99109          2.015090e+13  1.2.840.10008.5.1.4.1.1.66      OPT          R
# 104961         2.016051e+13  1.2.840.10008.5.1.4.1.1.66      OPT          L
#
#            seriesdescription  studydate  studytime doctype_non_standard_tag  \
# 85164   Glaucoma OU Analysis   20140211   163654.0    99CZM_NIM_INTERNAL_01
# 98721   Glaucoma OU Analysis   20150817   101015.0    99CZM_NIM_INTERNAL_01
# 99109   Glaucoma OU Analysis   20150902   173858.0    99CZM_NIM_INTERNAL_01
# 104961  Glaucoma OU Analysis   20160513    92005.0    99CZM_NIM_INTERNAL_01
#
#         averagernflthickness_micrometers  opticcupvolume_mm_squared  \
# 85164                         122.612701                        0.0
# 98721                         217.731598                        0.0
# 99109                         162.104904                        0.0
# 104961                        145.006393                        0.0
#
#         opticdiskarea_mm_squared  rimarea_mm_squared    avgcdr  verticalcd  \
# 85164                   5.988804            5.988804  0.036916    0.030000
# 98721                   7.267351            7.267351  0.033063    0.027523
# 99109                   7.480529            7.476209  0.033333    0.029703
# 104961                  7.766661            7.766661  0.032698    0.027523
#
#         year  month  day
# 85164   2014      2   11
# 98721   2015      8   17
# 99109   2015      9    2
# 104961  2016      5   13

# %%
df_cfp.dtypes
# Out:
# year           int64
# month          int64
# day            int64
# devname       object
# fileeye       object
# pat_mrn        int64
# cdr           object
# cdr_value    float64
# img_path      object
# dtype: object

# %%
df_cfp.dtypes
# Out:
# filename              object
# year                   int64
# month                  int64
# day                    int64
# devname               object
# fileeye_lateral       object
# pat_mrn                int64
# cdr_value_lateral    float64
# pred_cdr             float64
# dtype: object

# %%
len(df_oct)
# Out:
# 132689

# %%
# Ensure that MRNs are numeric for merging and do not contain 
df_oct['patientmrn'] = pd.to_numeric(df_oct['patientmrn'], errors='coerce')
# df_oct_cfp_merge_oct_cfp_merge_oct.dropna(subset=['patientmrn'], inplace=True)
df_oct.dropna(subset=['patientmrn'], inplace=True)
df_oct['patientmrn'] = df_oct['patientmrn'].astype(int)
print(df_oct.dtypes)
# df_oct['patientmrn'].count() -- 132592 after converting to numeric and dropping any rows that had alpha characters in the MRNs from OCT csv
# Out:
# filenamepath                         object
# patientmrn                            int64
# acquisitiondatetime                 float64
# sopclassuid                          object
# modality                             object
# laterality                           object
# seriesdescription                    object
# studydate                             int64
# studytime                           float64
# doctype_non_standard_tag             object
# averagernflthickness_micrometers    float64
# opticcupvolume_mm_squared           float64
# opticdiskarea_mm_squared            float64
# rimarea_mm_squared                  float64
# avgcdr                              float64
# verticalcd                          float64
# year                                  int64
# month                                 int64
# day                                   int64
# dtype: object

# %%
len(df_oct)
# Out:
# 132592

# %%
# Sanity check for merge 
float_rows_cfp = df_cfp[df_cfp['pat_mrn'] != df_cfp['pat_mrn'].astype(int)]

# Display these rows
print(float_rows_cfp)

float_rows_oct = df_oct[df_oct['patientmrn'] != df_oct['patientmrn'].astype(int)]

# Display these rows
print(float_rows_oct)
# Out:
# Empty DataFrame
# Columns: [filename, year, month, day, devname, fileeye_lateral, pat_mrn, cdr_value_lateral, pred_cdr]
# Index: []
# Empty DataFrame
# Columns: [filenamepath, patientmrn, acquisitiondatetime, sopclassuid, modality, laterality, seriesdescription, studydate, studytime, doctype_non_standard_tag, averagernflthickness_micrometers, opticcupvolume_mm_squared, opticdiskarea_mm_squared, rimarea_mm_squared, avgcdr, verticalcd, year, month, day]
# Index: []

# %%
# Merge the two CFP and OCT dfs
df_oct_cfp_merge = pd.merge(df_cfp, df_oct, left_on='pat_mrn', right_on='patientmrn')

# print(oct_cfp_merge_df.count())
print(df_oct_cfp_merge.count())
# Out:
# filename                            298607
# year_x                              298607
# month_x                             298607
# day_x                               298607
# devname                             298607
# fileeye_lateral                     298607
# pat_mrn                             298607
# cdr_value_lateral                   298607
# pred_cdr                            298607
# filenamepath                        298607
# patientmrn                          298607
# acquisitiondatetime                 298607
# sopclassuid                         298607
# modality                            298607
# laterality                          298607
# seriesdescription                   298607
# studydate                           298607
# studytime                           298607
# doctype_non_standard_tag            298607
# averagernflthickness_micrometers    298607
# opticcupvolume_mm_squared           298607
# opticdiskarea_mm_squared            298607
# rimarea_mm_squared                  298607
# avgcdr                              298607
# verticalcd                          298607
# year_y                              298607
# month_y                             298607
# day_y                               298607
# dtype: int64

# %%
# Dropping rows where we dont have matching laterality
df_oct_cfp_merge = df_oct_cfp_merge[df_oct_cfp_merge['fileeye'] != 'U']
drop_laterality_nonmatches =  df_oct_cfp_merge[~(((df_oct_cfp_merge['fileeye'] == 'OD') & (df_oct_cfp_merge['laterality'] == 'R')) | 
                        ((df_oct_cfp_merge['fileeye'] == 'OS') & (df_oct_cfp_merge['laterality'] == 'L')))].index
df_oct_cfp_merge.drop(drop_laterality_nonmatches, inplace=True)
print(df_oct_cfp_merge.count()) # 43810 total rows
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.virtualenvs/coris/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fileeye'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Dropping rows where we dont have matching laterality
# ----> 2 df_oct_cfp_merge = df_oct_cfp_merge[df_oct_cfp_merge['fileeye'] != 'U']
#       3 drop_laterality_nonmatches =  df_oct_cfp_merge[~(((df_oct_cfp_merge['fileeye'] == 'OD') & (df_oct_cfp_merge['laterality'] == 'R')) |
#       4                         ((df_oct_cfp_merge['fileeye'] == 'OS') & (df_oct_cfp_merge['laterality'] == 'L')))].index
#       5 df_oct_cfp_merge.drop(drop_laterality_nonmatches, inplace=True)
#
# File ~/.virtualenvs/coris/lib/python3.10/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/.virtualenvs/coris/lib/python3.10/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'fileeye'

# %%
# Dropping rows where we dont have matching laterality
# df_oct_cfp_merge = df_oct_cfp_merge[df_oct_cfp_merge['fileeye'] != 'U']
drop_laterality_nonmatches =  df_oct_cfp_merge[~(((df_oct_cfp_merge['fileeye_lateral'] == 'OD') & (df_oct_cfp_merge['laterality'] == 'R')) | 
                        ((df_oct_cfp_merge['fileeye_lateral'] == 'OS') & (df_oct_cfp_merge['laterality'] == 'L')))].index
df_oct_cfp_merge.drop(drop_laterality_nonmatches, inplace=True)
print(df_oct_cfp_merge.count()) # 43810 total rows
# Out:
# filename                            149525
# year_x                              149525
# month_x                             149525
# day_x                               149525
# devname                             149525
# fileeye_lateral                     149525
# pat_mrn                             149525
# cdr_value_lateral                   149525
# pred_cdr                            149525
# filenamepath                        149525
# patientmrn                          149525
# acquisitiondatetime                 149525
# sopclassuid                         149525
# modality                            149525
# laterality                          149525
# seriesdescription                   149525
# studydate                           149525
# studytime                           149525
# doctype_non_standard_tag            149525
# averagernflthickness_micrometers    149525
# opticcupvolume_mm_squared           149525
# opticdiskarea_mm_squared            149525
# rimarea_mm_squared                  149525
# avgcdr                              149525
# verticalcd                          149525
# year_y                              149525
# month_y                             149525
# day_y                               149525
# dtype: int64

# %%
# Check for missing values in the specified columns
print(df_oct_cfp_merge[['year_x', 'month_x', 'day_x', 'year_y', 'month_y', 'day_y']].isna().sum())

# Assuming no missing values or after handling them, convert to datetime
df_oct_cfp_merge['cfp_date'] = pd.to_datetime(df_oct_cfp_merge[['year_x', 'month_x', 'day_x']].rename(columns={'year_x': 'year', 'month_x': 'month', 'day_x': 'day'}))
df_oct_cfp_merge['oct_date'] = pd.to_datetime(df_oct_cfp_merge[['year_y', 'month_y', 'day_y']].rename(columns={'year_y': 'year', 'month_y': 'month', 'day_y': 'day'}))
# Out:
# year_x     0
# month_x    0
# day_x      0
# year_y     0
# month_y    0
# day_y      0
# dtype: int64

# %%
# Check for missing values in the specified columns
print(df_oct_cfp_merge[['year_x', 'month_x', 'day_x', 'year_y', 'month_y', 'day_y']].isna().sum())

# Assuming no missing values or after handling them, convert to datetime
df_oct_cfp_merge['cfp_date'] = pd.to_datetime(df_oct_cfp_merge[['year_x', 'month_x', 'day_x']].rename(columns={'year_x': 'year', 'month_x': 'month', 'day_x': 'day'}))
df_oct_cfp_merge['oct_date'] = pd.to_datetime(df_oct_cfp_merge[['year_y', 'month_y', 'day_y']].rename(columns={'year_y': 'year', 'month_y': 'month', 'day_y': 'day'}))
# Out:
# year_x     0
# month_x    0
# day_x      0
# year_y     0
# month_y    0
# day_y      0
# dtype: int64

# %%
# Convert to datetime and filter for OCT within 6 months (before or after CFP capture)

# Convert to datetime
# df_oct_cfp_merge['cfp_date'] = pd.to_datetime(df_oct_cfp_merge[['year_x', 'month_x', 'day_x']])
# df_oct_cfp_merge['oct_date'] = pd.to_datetime(df_oct_cfp_merge[['year_y', 'month_y', 'day_y']])

# Calculate the difference (this will be in Timedelta)
df_oct_cfp_merge['date_diff'] = (df_oct_cfp_merge['cfp_date'] - df_oct_cfp_merge['oct_date']).abs()

# Convert the Timedelta to months for easier comparison
# Note: timedelta.days will give you the difference in days, divide by ~30 to approximate months
df_oct_cfp_merge['diff_months'] = df_oct_cfp_merge['date_diff'].dt.days / 30

# Filter out rows where the difference is not within 6 months
# Keep rows where the difference is <= 6 months
df_oct_cfp_merge = df_oct_cfp_merge[df_oct_cfp_merge['diff_months'] <= 6]

# Optionally, if you want to drop the temporary columns created for this operation:
df_oct_cfp_merge.drop(columns=['date_diff'], inplace=True)

# df_filtered now contains only the rows that meet your condition
print(df_oct_cfp_merge.count()) # 4488 total rows
# Out:
# filename                            11890
# year_x                              11890
# month_x                             11890
# day_x                               11890
# devname                             11890
# fileeye_lateral                     11890
# pat_mrn                             11890
# cdr_value_lateral                   11890
# pred_cdr                            11890
# filenamepath                        11890
# patientmrn                          11890
# acquisitiondatetime                 11890
# sopclassuid                         11890
# modality                            11890
# laterality                          11890
# seriesdescription                   11890
# studydate                           11890
# studytime                           11890
# doctype_non_standard_tag            11890
# averagernflthickness_micrometers    11890
# opticcupvolume_mm_squared           11890
# opticdiskarea_mm_squared            11890
# rimarea_mm_squared                  11890
# avgcdr                              11890
# verticalcd                          11890
# year_y                              11890
# month_y                             11890
# day_y                               11890
# cfp_date                            11890
# oct_date                            11890
# diff_months                         11890
# dtype: int64
# /tmp/ipykernel_1934094/1719818828.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_oct_cfp_merge.drop(columns=['date_diff'], inplace=True)

# %%
# Convert to datetime and filter for OCT within 6 months (before or after CFP capture)

# Convert to datetime
# df_oct_cfp_merge['cfp_date'] = pd.to_datetime(df_oct_cfp_merge[['year_x', 'month_x', 'day_x']])
# df_oct_cfp_merge['oct_date'] = pd.to_datetime(df_oct_cfp_merge[['year_y', 'month_y', 'day_y']])

# Calculate the difference (this will be in Timedelta)
df_oct_cfp_merge['date_diff'] = (df_oct_cfp_merge['cfp_date'] - df_oct_cfp_merge['oct_date']).abs()

# Convert the Timedelta to months for easier comparison
# Note: timedelta.days will give you the difference in days, divide by ~30 to approximate months
df_oct_cfp_merge['diff_months'] = df_oct_cfp_merge['date_diff'].dt.days / 30

# Filter out rows where the difference is not within 6 months
# Keep rows where the difference is <= 6 months
df_oct_cfp_merge = df_oct_cfp_merge[df_oct_cfp_merge['diff_months'] <= 6]

# Optionally, if you want to drop the temporary columns created for this operation:
df_oct_cfp_merge.drop(columns=['date_diff'], inplace=True)

# df_filtered now contains only the rows that meet your condition
print(df_oct_cfp_merge.count()) # 4488 total rows
# Out:
# filename                            11890
# year_x                              11890
# month_x                             11890
# day_x                               11890
# devname                             11890
# fileeye_lateral                     11890
# pat_mrn                             11890
# cdr_value_lateral                   11890
# pred_cdr                            11890
# filenamepath                        11890
# patientmrn                          11890
# acquisitiondatetime                 11890
# sopclassuid                         11890
# modality                            11890
# laterality                          11890
# seriesdescription                   11890
# studydate                           11890
# studytime                           11890
# doctype_non_standard_tag            11890
# averagernflthickness_micrometers    11890
# opticcupvolume_mm_squared           11890
# opticdiskarea_mm_squared            11890
# rimarea_mm_squared                  11890
# avgcdr                              11890
# verticalcd                          11890
# year_y                              11890
# month_y                             11890
# day_y                               11890
# cfp_date                            11890
# oct_date                            11890
# diff_months                         11890
# dtype: int64
# /tmp/ipykernel_1934094/1719818828.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_oct_cfp_merge['date_diff'] = (df_oct_cfp_merge['cfp_date'] - df_oct_cfp_merge['oct_date']).abs()
# /tmp/ipykernel_1934094/1719818828.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_oct_cfp_merge['diff_months'] = df_oct_cfp_merge['date_diff'].dt.days / 30

# %%
df_oct_cfp_merge.head(10)
# Out:
#                                               filename  year_x  month_x  \
# 54   axis01_22166_571617_2022122109013895588103e45f...    2022       12
# 76   axis01_22166_571617_2022122109013864353fed39e3...    2022       12
# 97   axis01_22166_406878_20210222113120859d2a856d5d...    2021        1
# 121  axis01_22166_406878_20210222113141841da9d74d9b...    2021        1
# 259  axis01_59248_472825_202112010812083297896b52de...    2021       12
# 264  axis01_59248_472825_202112010812090774389702d5...    2021       12
# 313  axis01_19943_569840_202212140850046909d3103758...    2022       12
# 332  axis01_19943_476102_20211213093728807e61dd5f38...    2021       12
# 333  axis01_19943_476102_20211213093728807e61dd5f38...    2021       12
# 334  axis01_19943_476102_20211213093728807e61dd5f38...    2021       12
#
#      day_x devname fileeye_lateral  pat_mrn  cdr_value_lateral  pred_cdr  \
# 54      21   Nidek              OS  1055949               0.50  0.565217
# 76      21   Nidek              OD  1055949               0.65  0.507625
# 97       6   Nidek              OD  1055949               0.65  0.477876
# 121      6   Nidek              OS  1055949               0.60  0.585313
# 259      1   Nidek              OD  7911179               0.60  0.507692
# 264      1   Nidek              OS  7911179               0.85  0.683297
# 313     14   Nidek              OS  1840021               0.70  0.588106
# 332     13   Nidek              OS  1840021               0.70  0.581498
# 333     13   Nidek              OS  1840021               0.70  0.581498
# 334     13   Nidek              OS  1840021               0.70  0.581498
#
#                                           filenamepath  ...  \
# 54   /data/PACS/forum/2023/6/19/1.2.276.0.75.2.2.42...  ...
# 76   /data/PACS/forum/2023/6/19/1.2.276.0.75.2.2.42...  ...
# 97   /data/PACS/forum/2021/5/5/1.2.276.0.75.2.2.42....  ...
# 121  /data/PACS/forum/2021/5/5/1.2.276.0.75.2.2.42....  ...
# 259  /data/PACS/forum/2021/8/4/1.2.276.0.75.2.2.42....  ...
# 264  /data/PACS/forum/2021/8/4/1.2.276.0.75.2.2.42....  ...
# 313  /data/PACS/forum/2023/4/10/1.2.276.0.75.2.2.42...  ...
# 332  /data/PACS/forum/2021/8/16/1.2.276.0.75.2.2.42...  ...
# 333  /data/PACS/forum/2021/8/16/1.2.276.0.75.2.2.42...  ...
# 334  /data/PACS/forum/2021/8/16/1.2.276.0.75.2.2.42...  ...
#
#      opticdiskarea_mm_squared  rimarea_mm_squared    avgcdr verticalcd year_y  \
# 54                   1.760489            1.078310  0.608641   0.638298   2023
# 76                   1.347346            0.894865  0.562580   0.547619   2023
# 97                   1.494608            0.955991  0.595809   0.645833   2021
# 121                  1.407543            0.935498  0.574333   0.577778   2021
# 259                  1.670016            1.157344  0.543920   0.557692   2021
# 264                  1.848008            0.553841  0.835783   0.851852   2021
# 313                  1.671742            0.738678  0.739335   0.702128   2023
# 332                  1.693583            0.731999  0.752080   0.693878   2021
# 333                  1.678901            0.776016  0.727348   0.680851   2021
# 334                  1.633135            0.747804  0.730147   0.645833   2021
#
#     month_y  day_y   cfp_date   oct_date  diff_months
# 54        6     19 2022-12-21 2023-06-19     6.000000
# 76        6     19 2022-12-21 2023-06-19     6.000000
# 97        5      5 2021-01-06 2021-05-05     3.966667
# 121       5      5 2021-01-06 2021-05-05     3.966667
# 259       8      4 2021-12-01 2021-08-04     3.966667
# 264       8      4 2021-12-01 2021-08-04     3.966667
# 313       4     10 2022-12-14 2023-04-10     3.900000
# 332       8     16 2021-12-13 2021-08-16     3.966667
# 333       8     16 2021-12-13 2021-08-16     3.966667
# 334       8     16 2021-12-13 2021-08-16     3.966667
#
# [10 rows x 31 columns]

# %%
# Save new df to csv
df_oct_cfp_merge.to_csv('OCT_CFP_CDRs_preds.csv', index=False)

# %%
# Convert datetime columns to datetime format
df_oct_cfp_merge['cfp_datetime'] = pd.to_datetime(df_oct_cfp_merge['cfp_date'])
df_oct_cfp_merge['oct_datetime'] = pd.to_datetime(df_oct_cfp_merge['oct_date'])

# %%
df_oct_cfp_merge
# Out:
#                                                  filename  year_x  month_x  \
# 54      axis01_22166_571617_2022122109013895588103e45f...    2022       12
# 76      axis01_22166_571617_2022122109013864353fed39e3...    2022       12
# 97      axis01_22166_406878_20210222113120859d2a856d5d...    2021        1
# 121     axis01_22166_406878_20210222113141841da9d74d9b...    2021        1
# 259     axis01_59248_472825_202112010812083297896b52de...    2021       12
# ...                                                   ...     ...      ...
# 298463  axis01_24595_333345_2020020307434191069e500b32...    2020        1
# 298473  axis01_23869_329440_20200115084638470a9beb4b2e...    2020        1
# 298499  axis01_29054_300162_2019082109075899939457143b...    2019        8
# 298537  axis01_25884_285103_20190605091746077aafb03155...    2019        6
# 298564  axis01_24991_407151_20210222122001141f7a2ceeb7...    2019        4
#
#         day_x devname fileeye_lateral  pat_mrn  cdr_value_lateral  pred_cdr  \
# 54         21   Nidek              OS  1055949               0.50  0.565217
# 76         21   Nidek              OD  1055949               0.65  0.507625
# 97          6   Nidek              OD  1055949               0.65  0.477876
# 121         6   Nidek              OS  1055949               0.60  0.585313
# 259         1   Nidek              OD  7911179               0.60  0.507692
# ...       ...     ...             ...      ...                ...       ...
# 298463     29   Nidek              OS   742158               0.85  0.786957
# 298473     15   Nidek              OS   639184               0.60  0.569231
# 298499     21   Nidek              OS  1306791               0.60  0.557734
# 298537      5   Nidek              OS  4410757               0.70  0.667396
# 298564     15   Nidek              OS  4401429               0.75  0.665948
#
#                                              filenamepath  ...    avgcdr  \
# 54      /data/PACS/forum/2023/6/19/1.2.276.0.75.2.2.42...  ...  0.608641
# 76      /data/PACS/forum/2023/6/19/1.2.276.0.75.2.2.42...  ...  0.562580
# 97      /data/PACS/forum/2021/5/5/1.2.276.0.75.2.2.42....  ...  0.595809
# 121     /data/PACS/forum/2021/5/5/1.2.276.0.75.2.2.42....  ...  0.574333
# 259     /data/PACS/forum/2021/8/4/1.2.276.0.75.2.2.42....  ...  0.543920
# ...                                                   ...  ...       ...
# 298463  /data/PACS/forum/2020/5/28/1.2.276.0.75.2.2.42...  ...  0.840920
# 298473  /data/PACS/forum/2019/7/31/1.2.276.0.75.2.2.42...  ...  0.719236
# 298499  /data/PACS/forum/2019/12/2/1.2.276.0.75.2.2.42...  ...  0.676233
# 298537  /data/PACS/forum/2019/1/2/1.2.276.0.75.2.2.42....  ...  0.638466
# 298564  /data/PACS/forum/2018/12/10/1.2.276.0.75.2.2.4...  ...  0.736072
#
#         verticalcd year_y month_y day_y   cfp_date   oct_date  diff_months  \
# 54        0.638298   2023       6    19 2022-12-21 2023-06-19     6.000000
# 76        0.547619   2023       6    19 2022-12-21 2023-06-19     6.000000
# 97        0.645833   2021       5     5 2021-01-06 2021-05-05     3.966667
# 121       0.577778   2021       5     5 2021-01-06 2021-05-05     3.966667
# 259       0.557692   2021       8     4 2021-12-01 2021-08-04     3.966667
# ...            ...    ...     ...   ...        ...        ...          ...
# 298463    0.833333   2020       5    28 2020-01-29 2020-05-28     4.000000
# 298473    0.666667   2019       7    31 2020-01-15 2019-07-31     5.600000
# 298499    0.603448   2019      12     2 2019-08-21 2019-12-02     3.433333
# 298537    0.595238   2019       1     2 2019-06-05 2019-01-02     5.133333
# 298564    0.826923   2018      12    10 2019-04-15 2018-12-10     4.200000
#
#        cfp_datetime  oct_datetime
# 54       2022-12-21    2023-06-19
# 76       2022-12-21    2023-06-19
# 97       2021-01-06    2021-05-05
# 121      2021-01-06    2021-05-05
# 259      2021-12-01    2021-08-04
# ...             ...           ...
# 298463   2020-01-29    2020-05-28
# 298473   2020-01-15    2019-07-31
# 298499   2019-08-21    2019-12-02
# 298537   2019-06-05    2019-01-02
# 298564   2019-04-15    2018-12-10
#
# [11890 rows x 33 columns]

# %%
# Sort DataFrame by filename and value_datetime
df_avg = df_oct_cfp_merge.sort_values(by=['filename', 'oct_datetime'])

# Group by filename and value_datetime
grouped = df_avg.groupby(['filename', df_oct_cfp_merge['oct_datetime'].dt.date])

# Function to calculate the average value for each day
def calculate_average(group):
    return pd.Series([group['filename'].iloc[0], group['cfp_datetime'].iloc[0], group['oct_datetime'].iloc[0], group['verticalcd'].mean()], index=['filename', 'cfp_datetime', 'oct_datetime', 'verticalcd'])

# Apply average calculation function to each group
average_df = grouped.apply(calculate_average)

# Reset index
average_df.reset_index(drop=True, inplace=True)

# %%
average_df
# Out:
#                                                filename cfp_datetime  \
# 0     AxisUCH01_10002_60041_20140729132439549a8fbbbc...   2014-07-29
# 1     AxisUCH01_10002_60041_20140729132439611fd956f1...   2014-07-29
# 2     AxisUCH01_10034_77265_201502250751527525b51a9c...   2015-02-25
# 3     AxisUCH01_10034_77265_20150225075152924ecb69af...   2015-02-25
# 4     AxisUCH01_10048_60715_20140805131049845db950db...   2014-08-05
# ...                                                 ...          ...
# 8865  axis01_9976_202616_201801221340470714cf539312f...   2018-01-22
# 8866  axis01_9976_202616_201801221340473211adc10aa99...   2018-01-22
# 8867  axis01_9995_254659_2018112716004128898911f0137...   2018-11-27
# 8868  axis01_99_145707_2016121610000424228b44a50f6ca...   2016-12-16
# 8869  axis01_99_522768_20220610101336593255cf3dc700e...   2022-06-10
#
#      oct_datetime  verticalcd
# 0      2014-12-02    0.603774
# 1      2014-12-02    0.500000
# 2      2015-01-07    0.629630
# 3      2015-01-07    0.666667
# 4      2015-01-06    0.650794
# ...           ...         ...
# 8865   2017-09-25    0.721312
# 8866   2017-09-25    0.826087
# 8867   2018-11-27    0.510638
# 8868   2017-04-21    0.500000
# 8869   2022-02-08    0.548387
#
# [8870 rows x 4 columns]

# %%
average_df[average_df['filename'] == 'axis01_10118_301985_2019082913060251569f81ee505e22f9b.png']
# Out:
#                                                filename cfp_datetime  \
# 2839  axis01_10118_301985_2019082913060251569f81ee50...   2019-08-29
# 2840  axis01_10118_301985_2019082913060251569f81ee50...   2019-08-29
#
#      oct_datetime  verticalcd
# 2839   2019-03-07    0.623478
# 2840   2020-02-05    0.642538

# %%
# # Sort DataFrame by filename and value_datetime
# df_interp = average_df.sort_values(['filename', 'oct_datetime'])

# # Group by filename
# grouped = df_interp.groupby('filename')

# # Function to perform linear interpolation
# def interpolate(group):
#     # If there's only one value, return it directly
#     cfp_date = group['cfp_datetime'].iloc[0]
#     if len(group) == 1:
#         return group[['filename', 'cfp_datetime', 'verticalcd']].iloc[0]
#     elif cfp_date in group['oct_datetime'].values:
#         matching_row = group[group['oct_datetime'] == cfp_date]
#         if not matching_row.empty:
#             return matching_row[['filename', 'cfp_datetime', 'verticalcd']].iloc[0]
#     # Find the two nearest value_datetimes
#     group = group.reset_index(drop=True)
#     cfp_date = group['cfp_datetime'].iloc[0]
#     nearest_dates = group['oct_datetime'].iloc[[0, -1]]
    
#     # Determine the difference in days between cfp_date and the two nearest dates
#     days_diff = abs(nearest_dates - cfp_date).dt.days

#     # print(days_diff.iloc[1])
    
#     # Calculate weights for linear interpolation
#     weight_total = days_diff.sum()
#     weights = [(days_diff.iloc[1] / weight_total), (days_diff.iloc[0] / weight_total)]
    
#     # Get corresponding values for the nearest dates
#     nearest_values = group.loc[group['oct_datetime'].isin(nearest_dates), 'verticalcd']
    
#     # Interpolate between the two nearest values
#     interpolated_value = sum(weights[i] * nearest_values.iloc[i] for i in range(2))
    
#     return pd.Series([group['filename'].iloc[0], cfp_date, interpolated_value, 'hi'], index=['filename', 'cfp_datetime', 'verticalcd', 'oct_datetime'])
#     # return pd.Series([group['filename'].iloc[0], cfp_date, interpolated_value, nearest_dates.iloc[0], nearest_dates.iloc[1], nearest_values.iloc[0], nearest_values.iloc[1]], index=['filename', 'cfp_datetime', 'verticalcd', 'oct_before_date', 'oct_after_date', 'oct_before_value', 'oct_after_value'])

# # Apply interpolation function to each group
# interpolated_df = grouped.apply(interpolate)

# # Reset index
# interpolated_df.reset_index(drop=True, inplace=True)

# %%
# interpolated_df
# Out:
# 0        AxisUCH01_10002_60041_20140729132439549a8fbbbc...
# 1                                      2014-07-29 00:00:00
# 2                                                 0.603774
# 3        AxisUCH01_10002_60041_20140729132439611fd956f1...
# 4                                      2014-07-29 00:00:00
#                                ...
# 24838                                  2016-12-16 00:00:00
# 24839                                                  0.5
# 24840    axis01_99_522768_20220610101336593255cf3dc700e...
# 24841                                  2022-06-10 00:00:00
# 24842                                             0.548387
# Length: 24843, dtype: object

# %%
# Sort DataFrame by filename and value_datetime
df_interp = average_df.sort_values(['filename', 'oct_datetime'])
df_interp['oct_before_date'] = None
df_interp['oct_after_date'] = None
df_interp['oct_before_value'] = None
df_interp['oct_after_value'] = None

# Group by filename
grouped = df_interp.groupby('filename')

# Function to perform linear interpolation
def interpolate(group):
    # If there's only one value, return it directly
    cfp_date = group['cfp_datetime'].iloc[0]
    if len(group) == 1:
        return group[['filename', 'cfp_datetime', 'verticalcd', 'oct_before_date', 'oct_after_date', 'oct_before_value', 'oct_after_value']].iloc[0]
    elif cfp_date in group['oct_datetime'].values:
        matching_row = group[group['oct_datetime'] == cfp_date]
        if not matching_row.empty:
            return matching_row[['filename', 'cfp_datetime', 'verticalcd', 'oct_before_date', 'oct_after_date', 'oct_before_value', 'oct_after_value']].iloc[0]
    # Find the two nearest value_datetimes
    group = group.reset_index(drop=True)
    cfp_date = group['cfp_datetime'].iloc[0]
    nearest_dates = group['oct_datetime'].iloc[[0, -1]]
    
    # Determine the difference in days between cfp_date and the two nearest dates
    days_diff = abs(nearest_dates - cfp_date).dt.days

    # print(days_diff.iloc[1])
    
    # Calculate weights for linear interpolation
    weight_total = days_diff.sum()
    weights = [(days_diff.iloc[1] / weight_total), (days_diff.iloc[0] / weight_total)]
    
    # Get corresponding values for the nearest dates
    nearest_values = group.loc[group['oct_datetime'].isin(nearest_dates), 'verticalcd']
    
    # Interpolate between the two nearest values
    interpolated_value = sum(weights[i] * nearest_values.iloc[i] for i in range(2))
    
    return pd.Series([group['filename'].iloc[0], cfp_date, interpolated_value, nearest_dates.iloc[0], nearest_dates.iloc[1], nearest_values.iloc[0], nearest_values.iloc[1]], index=['filename', 'cfp_datetime', 'verticalcd', 'oct_before_date', 'oct_after_date', 'oct_before_value', 'oct_after_value'])

# Apply interpolation function to each group
interpolated_df = grouped.apply(interpolate)

# Reset index
interpolated_df.reset_index(drop=True, inplace=True)

# %%
interpolated_df.head(50)
# Out:
#                                              filename cfp_datetime  \
# 0   AxisUCH01_10002_60041_20140729132439549a8fbbbc...   2014-07-29
# 1   AxisUCH01_10002_60041_20140729132439611fd956f1...   2014-07-29
# 2   AxisUCH01_10034_77265_201502250751527525b51a9c...   2015-02-25
# 3   AxisUCH01_10034_77265_20150225075152924ecb69af...   2015-02-25
# 4   AxisUCH01_10048_60715_20140805131049845db950db...   2014-08-05
# 5   AxisUCH01_10048_60715_20140805131049938b8ba117...   2014-08-05
# 6   AxisUCH01_10062_120744_20160520133755017211352...   2016-05-20
# 7   AxisUCH01_10062_120744_201605201337551735a4625...   2016-05-20
# 8   AxisUCH01_10062_36088_2013090415210851529f3c9d...   2013-09-04
# 9   AxisUCH01_10062_36088_20130904152108624599d29b...   2013-09-04
# 10  AxisUCH01_10062_53888_201405071548115838093eb0...   2014-05-07
# 11  AxisUCH01_10062_53888_201405071548119429673839...   2014-05-07
# 12  AxisUCH01_10062_84210_20150518142630417dafff6f...   2015-05-18
# 13  AxisUCH01_10062_84210_2015051814263058863c15c8...   2015-05-18
# 14  AxisUCH01_10068_98991_20151022144253583218ddce...   2015-10-22
# 15  AxisUCH01_10068_98991_201510221442537546c5b67d...   2015-10-22
# 16  AxisUCH01_10086_96108_20150925112922870c055d58...   2015-09-25
# 17  AxisUCH01_10086_96108_20150925112923041b8ea82b...   2015-09-25
# 18  AxisUCH01_100_62692_20140829105654346559257af0...   2014-08-29
# 19  AxisUCH01_1011_41818_201311200812287674d32d959...   2013-11-20
# 20  AxisUCH01_1011_41818_20131120081228845f1e42df2...   2013-11-20
# 21  AxisUCH01_10128_106287_201601130932023598d3a7e...   2016-01-13
# 22  AxisUCH01_10128_106287_2016011309320251595271d...   2016-01-13
# 23  AxisUCH01_10128_59877_201407281132043386c1ec2e...   2014-07-28
# 24  AxisUCH01_10128_59877_20140728113204478a90de87...   2014-07-28
# 25  AxisUCH01_10182_48590_20140226132345574b6ec193...   2014-02-26
# 26  AxisUCH01_10182_48590_20140226132345636ec9224d...   2014-02-26
# 27  AxisUCH01_10184_40866_201311061548459173e3bdf5...   2013-11-06
# 28  AxisUCH01_10184_40866_20131106154846010f992000...   2013-11-06
# 29  AxisUCH01_10184_89921_20150722160036400d24e036...   2015-07-22
# 30  AxisUCH01_10184_89921_20150722160036556db2b1c8...   2015-07-22
# 31  AxisUCH01_10189_110197_20160222092335246f58079...   2016-02-22
# 32  AxisUCH01_10189_110197_2016022209233543433ed91...   2016-02-22
# 33  AxisUCH01_10321_111772_201603071338104959b8ecf...   2016-03-07
# 34  AxisUCH01_10321_111772_2016030713381063553e5fa...   2016-03-07
# 35  AxisUCH01_10323_80507_2015040713144321768a4351...   2015-04-07
# 36  AxisUCH01_10323_80507_201504071314433887d7d0f2...   2015-04-07
# 37  AxisUCH01_10342_43079_20131206164718450f7a6c50...   2013-12-06
# 38  AxisUCH01_10355_94782_201509111412224337734e6c...   2015-09-11
# 39  AxisUCH01_10355_94782_20150911141222589bc16c90...   2015-09-11
# 40  AxisUCH01_10363_84471_20150520162043864816ceee...   2015-05-20
# 41  AxisUCH01_10363_84471_20150520162044052638cb75...   2015-05-20
# 42  AxisUCH01_10432_41216_201311111442528378f7b5c3...   2013-11-11
# 43  AxisUCH01_10432_88333_20150702150731558c47096a...   2015-07-02
# 44  AxisUCH01_10432_88333_20150702150731730f1e5e59...   2015-07-02
# 45  AxisUCH01_10432_88333_201507021622340033683cb9...   2015-07-02
# 46  AxisUCH01_10432_88333_201507021637044797a4f503...   2015-07-02
# 47  AxisUCH01_10435_101697_20151119152718100402833...   2015-11-19
# 48  AxisUCH01_10435_45954_20140117152349768b4ef205...   2014-01-17
# 49  AxisUCH01_10435_45954_2014011715234984633d06c0...   2014-01-17
#
#     verticalcd oct_before_date oct_after_date  oct_before_value  \
# 0     0.603774             NaT            NaT               NaN
# 1     0.500000             NaT            NaT               NaN
# 2     0.629630             NaT            NaT               NaN
# 3     0.666667             NaT            NaT               NaN
# 4     0.650794             NaT            NaT               NaN
# 5     0.625000             NaT            NaT               NaN
# 6     0.824561             NaT            NaT               NaN
# 7     0.764706             NaT            NaT               NaN
# 8     0.843137             NaT            NaT               NaN
# 9     0.803571             NaT            NaT               NaN
# 10    0.803571             NaT            NaT               NaN
# 11    0.843137             NaT            NaT               NaN
# 12    0.803922             NaT            NaT               NaN
# 13    0.811321             NaT            NaT               NaN
# 14    0.471698             NaT            NaT               NaN
# 15    0.431154             NaT            NaT               NaN
# 16    0.741935             NaT            NaT               NaN
# 17    0.672131             NaT            NaT               NaN
# 18    0.672414             NaT            NaT               NaN
# 19    0.840435      2013-06-17     2014-04-09          0.851852
# 20    0.712560      2013-06-17     2014-04-09          0.720000
# 21    0.622863             NaT            NaT               NaN
# 22    0.645503             NaT            NaT               NaN
# 23    0.603989             NaT            NaT               NaN
# 24    0.605387             NaT            NaT               NaN
# 25    0.732143             NaT            NaT               NaN
# 26    0.697138             NaT            NaT               NaN
# 27    0.875926             NaT            NaT               NaN
# 28    0.586207             NaT            NaT               NaN
# 29    0.820470             NaT            NaT               NaN
# 30    0.603448             NaT            NaT               NaN
# 31    0.660000             NaT            NaT               NaN
# 32    0.722222             NaT            NaT               NaN
# 33    0.854839             NaT            NaT               NaN
# 34    0.741935             NaT            NaT               NaN
# 35    0.736842             NaT            NaT               NaN
# 36    0.774194             NaT            NaT               NaN
# 37    0.603175             NaT            NaT               NaN
# 38    0.867925             NaT            NaT               NaN
# 39    0.849057             NaT            NaT               NaN
# 40    0.062796      2014-12-15     2015-10-22          0.061755
# 41    0.260800      2014-12-15     2015-10-22          0.282609
# 42    0.711111             NaT            NaT               NaN
# 43    0.756583             NaT            NaT               NaN
# 44    0.747585             NaT            NaT               NaN
# 45    0.747585             NaT            NaT               NaN
# 46    0.756583             NaT            NaT               NaN
# 47    0.058824             NaT            NaT               NaN
# 48    0.054269             NaT            NaT               NaN
# 49    0.055051             NaT            NaT               NaN
#
#     oct_after_value
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19         0.830189
# 20         0.705882
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# 30              NaN
# 31              NaN
# 32              NaN
# 33              NaN
# 34              NaN
# 35              NaN
# 36              NaN
# 37              NaN
# 38              NaN
# 39              NaN
# 40         0.063830
# 41         0.239130
# 42              NaN
# 43              NaN
# 44              NaN
# 45              NaN
# 46              NaN
# 47              NaN
# 48              NaN
# 49              NaN

# %%
interpolated_df
# Out:
#                                                filename cfp_datetime  \
# 0     AxisUCH01_10002_60041_20140729132439549a8fbbbc...   2014-07-29
# 1     AxisUCH01_10002_60041_20140729132439611fd956f1...   2014-07-29
# 2     AxisUCH01_10034_77265_201502250751527525b51a9c...   2015-02-25
# 3     AxisUCH01_10034_77265_20150225075152924ecb69af...   2015-02-25
# 4     AxisUCH01_10048_60715_20140805131049845db950db...   2014-08-05
# ...                                                 ...          ...
# 8020  axis01_9976_202616_201801221340470714cf539312f...   2018-01-22
# 8021  axis01_9976_202616_201801221340473211adc10aa99...   2018-01-22
# 8022  axis01_9995_254659_2018112716004128898911f0137...   2018-11-27
# 8023  axis01_99_145707_2016121610000424228b44a50f6ca...   2016-12-16
# 8024  axis01_99_522768_20220610101336593255cf3dc700e...   2022-06-10
#
#       verticalcd
# 0       0.603774
# 1       0.500000
# 2       0.629630
# 3       0.666667
# 4       0.650794
# ...          ...
# 8020    0.721312
# 8021    0.826087
# 8022    0.510638
# 8023    0.500000
# 8024    0.548387
#
# [8025 rows x 3 columns]

# %%
interpolated_df[interpolated_df['filename'] == 'axis01_10118_301985_2019082913060251569f81ee505e22f9b.png']
# Out:
#                                                filename cfp_datetime  \
# 2592  axis01_10118_301985_2019082913060251569f81ee50...   2019-08-29
#
#       verticalcd oct_before_date oct_after_date  oct_before_value  \
# 2592    0.633435      2019-03-07     2020-02-05          0.623478
#
#       oct_after_value
# 2592         0.642538

# %%
interpolated_df.to_csv('/projects/coris_db/postgres/queries_and_stats/queries/Glaucoma/OCT_CDR_CFP_Merge/OCT_CFP_CDRs_interpolated.csv', index=False)

# %%
df_oct_cfp_merge[df_oct_cfp_merge['filename'] == 'axis01_10118_301985_2019082913060251569f81ee505e22f9b.png']
# Out:
#                                                  filename  year_x  month_x  \
# 105716  axis01_10118_301985_2019082913060251569f81ee50...    2019        8
# 105717  axis01_10118_301985_2019082913060251569f81ee50...    2019        8
# 105721  axis01_10118_301985_2019082913060251569f81ee50...    2019        8
# 105722  axis01_10118_301985_2019082913060251569f81ee50...    2019        8
# 105724  axis01_10118_301985_2019082913060251569f81ee50...    2019        8
# 105726  axis01_10118_301985_2019082913060251569f81ee50...    2019        8
#
#         day_x devname fileeye_lateral  pat_mrn  cdr_value_lateral  pred_cdr  \
# 105716     29  NonMyd              OS  1631259                0.3   0.60793
# 105717     29  NonMyd              OS  1631259                0.3   0.60793
# 105721     29  NonMyd              OS  1631259                0.3   0.60793
# 105722     29  NonMyd              OS  1631259                0.3   0.60793
# 105724     29  NonMyd              OS  1631259                0.3   0.60793
# 105726     29  NonMyd              OS  1631259                0.3   0.60793
#
#                                              filenamepath  ...    avgcdr  \
# 105716  /data/PACS/forum/2019/3/7/1.2.276.0.75.2.2.42....  ...  0.596164
# 105717  /data/PACS/forum/2019/3/7/1.2.276.0.75.2.2.42....  ...  0.596878
# 105721  /data/PACS/forum/2020/2/5/1.2.276.0.75.2.2.42....  ...  0.558898
# 105722  /data/PACS/forum/2020/2/5/1.2.276.0.75.2.2.42....  ...  0.595157
# 105724  /data/PACS/forum/2020/2/5/1.2.276.0.75.2.2.42....  ...  0.595157
# 105726  /data/PACS/forum/2020/2/5/1.2.276.0.75.2.2.42....  ...  0.606504
#
#         verticalcd year_y month_y day_y   cfp_date   oct_date  diff_months  \
# 105716    0.586957   2019       3     7 2019-08-29 2019-03-07     5.833333
# 105717    0.660000   2019       3     7 2019-08-29 2019-03-07     5.833333
# 105721    0.632653   2020       2     5 2019-08-29 2020-02-05     5.333333
# 105722    0.645833   2020       2     5 2019-08-29 2020-02-05     5.333333
# 105724    0.645833   2020       2     5 2019-08-29 2020-02-05     5.333333
# 105726    0.645833   2020       2     5 2019-08-29 2020-02-05     5.333333
#
#        cfp_datetime  oct_datetime
# 105716   2019-08-29    2019-03-07
# 105717   2019-08-29    2019-03-07
# 105721   2019-08-29    2020-02-05
# 105722   2019-08-29    2020-02-05
# 105724   2019-08-29    2020-02-05
# 105726   2019-08-29    2020-02-05
#
# [6 rows x 33 columns]

# %%
# Get value counts of 'filename' column
print(df_oct_cfp_merge['filename'].value_counts()[:20])
# Out:
# filename
# AxisUCH01_79_91756_20150811100805090c99754bad1cf0d6b.png     11
# axis01_9971_159418_20170405080912059df040672c4d2f10f.png     10
# axis01_9971_159418_20170405080911950c6bbc2c22f48d559.png     10
# axis01_10184_260492_2019010715471977084a9c12c80729d89.png     7
# axis01_10086_237983_201808151350030101c6a6edb4c05b1cb.png     7
# axis01_10184_260492_20190107154720066691402caeeb46343.png     7
# axis01_12883_192566_20171109104955881e0dce737207fdb4c.png     6
# axis01_17416_276772_20190419102811916fabacd8f4473c47b.png     6
# axis01_17416_276772_20190419102812103f0bb2f65f4af43cb.png     6
# axis01_10682_269450_20190304135326692ad7b99a8a74d288c.png     6
# AxisUCH01_5572_57600_2014062410114722692cd30ae068d0c4.png     6
# axis01_10118_301985_2019082913060251569f81ee505e22f9b.png     6
# axis01_7197_389667_202012011448430279d803d490d97e7f1.png      6
# axis01_6258_172874_201707100810388394919327e0104679c.png      6
# axis01_48856_394122_20201221132546573a8223c0ad6ee2ec5.png     6
# axis01_24541_217659_20180420141520148a11360039f6c09c7.png     6
# axis01_28347_350933_20200610144853609d656302af90b426a.png     6
# axis01_48856_394122_20201221132546667140d972d29a3d46d.png     6
# axis01_1011_187205_201710160733523208cdb64c6c78de7e0.png      6
# axis01_18242_208899_20180302144519677676963f2ed1d2a86.png     6
# Name: count, dtype: int64

# %%
interpolated_df.loc[:10, 'filename'][1]
# Out:
# 'AxisUCH01_10002_60041_20140729132439611fd956f1c3f746c3f.png'

# %%
# Identify duplicate rows based on column 'A'
duplicate_rows = interpolated[interpolated.duplicated(subset=['filename'], keep=False)]
# Out:
# Original DataFrame:
#                                                 filename oct_datetime  \
# 14     AxisUCH01_10068_98991_20151022144253583218ddce...   2015-06-11
# 15     AxisUCH01_10068_98991_20151022144253583218ddce...   2015-06-11
# 16     AxisUCH01_10068_98991_201510221442537546c5b67d...   2015-06-11
# 17     AxisUCH01_10068_98991_201510221442537546c5b67d...   2015-06-11
# 21     AxisUCH01_1011_41818_201311200812287674d32d959...   2013-06-17
# ...                                                  ...          ...
# 11880  axis01_9971_159418_20170405080912059df040672c4...   2017-08-02
# 11881  axis01_9976_158094_20170323083817871a0b30d4f34...   2016-11-17
# 11882  axis01_9976_158094_20170323083817871a0b30d4f34...   2016-11-17
# 11883  axis01_9976_158094_20170323083817934d28ddfafcf...   2016-11-17
# 11884  axis01_9976_158094_20170323083817934d28ddfafcf...   2016-11-17
#
#        interpolated_verticalcd
# 14                    0.490566
# 15                    0.452830
# 16                    0.420000
# 17                    0.442308
# 21                    0.851852
# ...                        ...
# 11880                 0.760000
# 11881                 0.890909
# 11882                 0.818182
# 11883                 0.704918
# 11884                 0.733333
#
# [6584 rows x 3 columns]

# %%
duplicate_rows
# Out:
#                                                 filename oct_datetime  \
# 14     AxisUCH01_10068_98991_20151022144253583218ddce...   2015-06-11
# 15     AxisUCH01_10068_98991_20151022144253583218ddce...   2015-06-11
# 16     AxisUCH01_10068_98991_201510221442537546c5b67d...   2015-06-11
# 17     AxisUCH01_10068_98991_201510221442537546c5b67d...   2015-06-11
# 21     AxisUCH01_1011_41818_201311200812287674d32d959...   2013-06-17
# ...                                                  ...          ...
# 11880  axis01_9971_159418_20170405080912059df040672c4...   2017-08-02
# 11881  axis01_9976_158094_20170323083817871a0b30d4f34...   2016-11-17
# 11882  axis01_9976_158094_20170323083817871a0b30d4f34...   2016-11-17
# 11883  axis01_9976_158094_20170323083817934d28ddfafcf...   2016-11-17
# 11884  axis01_9976_158094_20170323083817934d28ddfafcf...   2016-11-17
#
#        interpolated_verticalcd
# 14                    0.490566
# 15                    0.452830
# 16                    0.420000
# 17                    0.442308
# 21                    0.851852
# ...                        ...
# 11880                 0.760000
# 11881                 0.890909
# 11882                 0.818182
# 11883                 0.704918
# 11884                 0.733333
#
# [6584 rows x 3 columns]

# %%
# Drop duplicates across specified columns
df_oct_cfp_merge_no_dupe = df_oct_cfp_merge.drop_duplicates(subset=['filename'], keep='first')

# %%
df_oct_cfp_merge_no_dupe
# Out:
#                                                  filename  year_x  month_x  \
# 54      axis01_22166_571617_2022122109013895588103e45f...    2022       12
# 76      axis01_22166_571617_2022122109013864353fed39e3...    2022       12
# 97      axis01_22166_406878_20210222113120859d2a856d5d...    2021        1
# 121     axis01_22166_406878_20210222113141841da9d74d9b...    2021        1
# 259     axis01_59248_472825_202112010812083297896b52de...    2021       12
# ...                                                   ...     ...      ...
# 298463  axis01_24595_333345_2020020307434191069e500b32...    2020        1
# 298473  axis01_23869_329440_20200115084638470a9beb4b2e...    2020        1
# 298499  axis01_29054_300162_2019082109075899939457143b...    2019        8
# 298537  axis01_25884_285103_20190605091746077aafb03155...    2019        6
# 298564  axis01_24991_407151_20210222122001141f7a2ceeb7...    2019        4
#
#         day_x devname fileeye_lateral  pat_mrn  cdr_value_lateral  pred_cdr  \
# 54         21   Nidek              OS  1055949               0.50  0.565217
# 76         21   Nidek              OD  1055949               0.65  0.507625
# 97          6   Nidek              OD  1055949               0.65  0.477876
# 121         6   Nidek              OS  1055949               0.60  0.585313
# 259         1   Nidek              OD  7911179               0.60  0.507692
# ...       ...     ...             ...      ...                ...       ...
# 298463     29   Nidek              OS   742158               0.85  0.786957
# 298473     15   Nidek              OS   639184               0.60  0.569231
# 298499     21   Nidek              OS  1306791               0.60  0.557734
# 298537      5   Nidek              OS  4410757               0.70  0.667396
# 298564     15   Nidek              OS  4401429               0.75  0.665948
#
#                                              filenamepath  ...  \
# 54      /data/PACS/forum/2023/6/19/1.2.276.0.75.2.2.42...  ...
# 76      /data/PACS/forum/2023/6/19/1.2.276.0.75.2.2.42...  ...
# 97      /data/PACS/forum/2021/5/5/1.2.276.0.75.2.2.42....  ...
# 121     /data/PACS/forum/2021/5/5/1.2.276.0.75.2.2.42....  ...
# 259     /data/PACS/forum/2021/8/4/1.2.276.0.75.2.2.42....  ...
# ...                                                   ...  ...
# 298463  /data/PACS/forum/2020/5/28/1.2.276.0.75.2.2.42...  ...
# 298473  /data/PACS/forum/2019/7/31/1.2.276.0.75.2.2.42...  ...
# 298499  /data/PACS/forum/2019/12/2/1.2.276.0.75.2.2.42...  ...
# 298537  /data/PACS/forum/2019/1/2/1.2.276.0.75.2.2.42....  ...
# 298564  /data/PACS/forum/2018/12/10/1.2.276.0.75.2.2.4...  ...
#
#         opticdiskarea_mm_squared  rimarea_mm_squared    avgcdr verticalcd  \
# 54                      1.760489            1.078310  0.608641   0.638298
# 76                      1.347346            0.894865  0.562580   0.547619
# 97                      1.494608            0.955991  0.595809   0.645833
# 121                     1.407543            0.935498  0.574333   0.577778
# 259                     1.670016            1.157344  0.543920   0.557692
# ...                          ...                 ...       ...        ...
# 298463                  1.896901            0.565934  0.840920   0.833333
# 298473                  1.499965            0.727867  0.719236   0.666667
# 298499                  2.185613            1.163714  0.676233   0.603448
# 298537                  1.181392            0.672376  0.638466   0.595238
# 298564                  1.640456            0.735289  0.736072   0.826923
#
#        year_y month_y  day_y   cfp_date   oct_date  diff_months
# 54       2023       6     19 2022-12-21 2023-06-19     6.000000
# 76       2023       6     19 2022-12-21 2023-06-19     6.000000
# 97       2021       5      5 2021-01-06 2021-05-05     3.966667
# 121      2021       5      5 2021-01-06 2021-05-05     3.966667
# 259      2021       8      4 2021-12-01 2021-08-04     3.966667
# ...       ...     ...    ...        ...        ...          ...
# 298463   2020       5     28 2020-01-29 2020-05-28     4.000000
# 298473   2019       7     31 2020-01-15 2019-07-31     5.600000
# 298499   2019      12      2 2019-08-21 2019-12-02     3.433333
# 298537   2019       1      2 2019-06-05 2019-01-02     5.133333
# 298564   2018      12     10 2019-04-15 2018-12-10     4.200000
#
# [8025 rows x 31 columns]

# %%
# Save new df to csv
df_oct_cfp_merge_no_dupe.to_csv('OCT_CFP_CDRs_preds_nodupes.csv', index=False)
